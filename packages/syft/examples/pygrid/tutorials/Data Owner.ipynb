# %% [markdown]
# ## Initial Setup

# %%
import syft as sy
import torch as th

# create owner login
sy.login().setup(url="http://35.198.113.143:5000", email="juan.ferrer2.next@bbva.com", password="ownerpwd")
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=9, connect=2, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7efdf4b76310>: Failed to establish a new connection: [Errno 111] Connection refused')': /metadata
# WARNING:urllib3.connectionpool:Retrying (Retry(total=8, connect=1, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7efdf47864f0>: Failed to establish a new connection: [Errno 111] Connection refused')': /metadata
# WARNING:urllib3.connectionpool:Retrying (Retry(total=7, connect=0, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7efdf4b765b0>: Failed to establish a new connection: [Errno 111] Connection refused')': /metadata
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     168         try:
# --> 169             conn = connection.create_connection(
#     170                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      95     if err is not None:
# ---> 96         raise err
#      97
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     393             else:
# --> 394                 conn.request(method, url, **httplib_request_kw)
#     395
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connection.py in request(self, method, url, body, headers)
#     233             headers["User-Agent"] = _get_default_user_agent()
# --> 234         super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#     235
#
# ~/miniconda3/envs/pysyft/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1256         """Send a complete request to the server."""
# -> 1257         self._send_request(method, url, body, headers, encode_chunked)
#    1258
#
# ~/miniconda3/envs/pysyft/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1302             body = _encode(body, 'body')
# -> 1303         self.endheaders(body, encode_chunked=encode_chunked)
#    1304
#
# ~/miniconda3/envs/pysyft/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1251             raise CannotSendHeader()
# -> 1252         self._send_output(message_body, encode_chunked=encode_chunked)
#    1253
#
# ~/miniconda3/envs/pysyft/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1011         del self._buffer[:]
# -> 1012         self.send(msg)
#    1013
#
# ~/miniconda3/envs/pysyft/lib/python3.9/http/client.py in send(self, data)
#     951             if self.auto_open:
# --> 952                 self.connect()
#     953             else:
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connection.py in connect(self)
#     199     def connect(self):
# --> 200         conn = self._new_conn()
#     201         self._prepare_conn(conn)
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connection.py in _new_conn(self)
#     180         except SocketError as e:
# --> 181             raise NewConnectionError(
#     182                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x7efdf4b76820>: Failed to establish a new connection: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     782             )
# --> 783             return self.urlopen(
#     784                 method,
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     573         if new_retry.is_exhausted():
# --> 574             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     575
#
# MaxRetryError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /metadata (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7efdf4b76820>: Failed to establish a new connection: [Errno 111] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-6-c1c1e648acf1> in <module>
#       3
#       4 # create owner login
# ----> 5 sy.login().setup(url="http://35.198.111.91:5000", email="juan.ferrer2.next@bbva.com", password="ownerpwd")
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/syft/grid/client/client.py in login(email, password, url, conn_type)
#     258         credentials = {"email": email, "password": password}
#     259
# --> 260     return connect(url=url, credentials=credentials, conn_type=conn_type)
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/syft/grid/client/client.py in connect(url, conn_type, credentials, user_key)
#     234     user_key: Optional[SigningKey] = None,
#     235 ) -> GridClient:
# --> 236     return GridClient(
#     237         credentials=credentials,
#     238         url=url,
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/syft/grid/client/client.py in __init__(self, credentials, url, conn_type, client_type, user_key)
#      70             _user_key = SigningKey(_user_key.encode(), encoder=HexEncoder)
#      71         else:
# ---> 72             metadata = self.conn._get_metadata()  # type: ignore
#      73             if not user_key:
#      74                 _user_key = SigningKey.generate()
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/syft/grid/client/grid_connection.py in _get_metadata(self)
#     102         session.mount("https://", adapter)
#     103
# --> 104         response = session.get(self.base_url + "/metadata")
#     105         content = json.loads(response.text)
#     106
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/requests/sessions.py in get(self, url, **kwargs)
#     553
#     554         kwargs.setdefault('allow_redirects', True)
# --> 555         return self.request('GET', url, **kwargs)
#     556
#     557     def options(self, url, **kwargs):
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/miniconda3/envs/pysyft/lib/python3.9/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# ConnectionError: HTTPConnectionPool(host='127.0.0.1', port=5000): Max retries exceeded with url: /metadata (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x7efdf4b76820>: Failed to establish a new connection: [Errno 111] Connection refused'))

# %% [markdown]
# ### Log in as Owner

# %%
domain = sy.login(url="http://35.198.113.143:5000", email="juan.ferrer2.next@bbva.com", password="ownerpwd")

# %% [markdown]
# ### Upload a Dataset

# %%
dataset = domain.datasets.create('diabetes-dataset.tar.gz')

# %%
domain.datasets
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>manifest</th>
#       <th>description</th>
#       <th>tags</th>
#       <th>data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>f162ba41-8a71-4f22-a5c1-cfa677f36073</td>
#       <td>This dataset is originally from the National I...</td>
#       <td>This dataset is originally from the National I...</td>
#       <td>[#diabetes, #pima-indians-database]</td>
#       <td>[{'name': 'diabetes-data/data_02.csv', 'id': '...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
domain.datasets[0]
# Out:
# <syft.grid.client.request_api.dataset_api.Dataset object at 0x7efdf5220490><br /><br /><b>Id: </b>f162ba41-8a71-4f22-a5c1-cfa677f36073<br /><b>Tags: </b>['#diabetes', '#pima-indians-database']<br /><b>Manifest: </b>This dataset is originally from the National Institute of Diabetes and Digestive and Kidney Diseases. The objective is to predict based on diagnostic measurements whether a patient has diabetes.
#
# Several constraints were placed on the selection of these instances from a larger database. In particular, all patients here are females at least 21 years old of Pima Indian heritage.
#
# Diabetes files consist of 8 fields per record.  Each field is
# separated by a comma and each record is separated by a newline.
#
# CSV Columns and format:
# (1) Pregnancies (Integer) : Number of times pregnant
# (2) Glucose (Integer) : Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# (3) Blood Pressure (Integer) : Diastolic blood pressure (mm Hg)
# (4) Skin Thickness (Integer) : Triceps skin fold thickness (mm)
# (5) Insulin (Integer) : 2-Hour serum insulin (mu U/ml)
# (6) BMI (Float) : Body mass index (weight in kg/(height in m)^2)
# (6) Diabetes Pedigree (Float) : Diabetes Pedigree Function
# (7) Age (Integer): Patient's age (years)
# (8) Outcome (Integer): Class variable (0 or 1)
# <br /><br /><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>name</th>
#       <th>id</th>
#       <th>dtype</th>
#       <th>shape</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>diabetes-data/data_02.csv</td>
#       <td>79941c8c-44d8-424d-acd5-8684d35f5027</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>diabetes-data/data_06.csv</td>
#       <td>c740b287-ad10-4573-adc9-4ce9c2c738b8</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>diabetes-data/data_10.csv</td>
#       <td>9656e9e1-ed65-4262-8ea7-2047cee81b19</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>diabetes-data/data_03.csv</td>
#       <td>42211208-224b-42c4-850c-fd89ba81c5c5</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>diabetes-data/data_04.csv</td>
#       <td>2fde3d6a-b7f4-40c9-ac7c-b464ee41f9b9</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>diabetes-data/new_data.csv</td>
#       <td>cc793ca3-d422-4b79-a397-2ac4806e5f03</td>
#       <td>Tensor</td>
#       <td>(2000, 9)</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>diabetes-data/data_07.csv</td>
#       <td>d24ed67a-aadc-4851-b37a-20c5b183b932</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>diabetes-data/data_08.csv</td>
#       <td>25e03986-9939-4441-b63b-40415bab813d</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>diabetes-data/data_09.csv</td>
#       <td>467b2093-e579-4b52-99ab-85e28a99c1d6</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>diabetes-data/data_05.csv</td>
#       <td>8d9c5291-5e48-40a5-986e-20cd8de42ef3</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>diabetes-data/data_01.csv</td>
#       <td>f848f773-fc33-43d7-8d48-1ff65b242680</td>
#       <td>Tensor</td>
#       <td>(200, 9)</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ### Create a Data Compliance Officer

# %%
domain.roles.all(pandas=True)
# Out:
#    id                name  can_triage_requests  can_edit_settings  \
# 0   1                User                False              False
# 1   2  Compliance Officer                 True              False
# 2   3       Administrator                 True               True
# 3   4               Owner                 True               True
#
#    can_create_users  can_create_groups  can_edit_roles  \
# 0             False              False           False
# 1             False              False           False
# 2              True               True           False
# 3              True               True            True
#
#    can_manage_infrastructure  can_upload_data
# 0                      False            False
# 1                      False            False
# 2                      False             True
# 3                       True             True

# %%
domain.users.create(
    email="compliance@myorg.com", password="pwd123", role="Compliance Officer"
)

# %%
domain.users.all(pandas=True)
# Out:
#    id                       email  \
# 0   1  juan.ferrer2.next@bbva.com
# 1   2             admin@email.com
# 2   3             user2@email.com
# 3   4             user3@email.com
# 4   5             user4@email.com
# 5   6             user5@email.com
# 6   7            admin2@email.com
# 7   8        compliance@myorg.com
#
#                                          private_key  \
# 0  6e76eb56b8561eba8c10adbf941b1bf9b30ee45a369f8e...
# 1  fc6f38b5cf37e0a09dbd451e829a9f26e58c6b8ed3dd10...
# 2  b9bee500d5c71eeef01c5e4a74f2db4fb20f7bb63717f7...
# 3  dd53bd9e2f4dd106780d45fcfc5e15e7821ade18a59e86...
# 4  c24f1a161bc07ce757bfe743931793dcba2cb905b7330e...
# 5  ba9185fe74dfb060231662d7fbaab5f12e5a77190ef9fa...
# 6  7967d5aecdbc115b7a401abd9380f30892f8cc1c8419f7...
# 7  fb2d469328a427e28d522796ed2df2176d259210aa241a...
#
#                                           verify_key  role groups
# 0  88af5c8dd36b478978a04c719310497a3e5a227061c080...     4     []
# 1  6571560d1a13cc39f92db109e60d285a81ecdefac6ffe1...     1     []
# 2  d75654915b9c34db03eee78f12c596f0a609747b53642e...     1     []
# 3  cf6eae6856bf11cdc4d196bacb08cc9bf3155072baa43f...     1     []
# 4  9bc6080f99ff335b9ed21cca19b4cefacfbe24aed7b658...     1     []
# 5  7e84099b6ca8e07f7ed1ac711facf14da8e47257a12565...     1     []
# 6  9e2ccc6307319fb3e28461141cbc78d6fb939cc1c0a061...     1     []
# 7  3b1283e03d0fb663e2028127d3ffbafd188b76b58cc573...     2     []
